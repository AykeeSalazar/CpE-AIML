# %% [markdown]
# <a href="https://colab.research.google.com/github/AykeeSalazar/CpE-AIML/blob/main/58034_LabNo.1_Coesa/COESA_First_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Laboratory 1 - Software Engineering**
# ---
#
# © COESA <br>
# Castillo, James A.<br>
# Hernandez, Drixter V. <br>
# Medina, Daryll John O. <br>
# Salazar, Angelica Mhay C.

# %% [markdown]
# ### Task 1: Setting the Class Grades
# 1. Create variable declarations for:
#         - Last Names
#         - First Names
#         - Grades for Prelims
#         - Grades for Midterms
#         - Grades for Finals
# 2. Create a DataFrame (Pandas) for consolidating the data from Task 1.1

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame as df

# %%
# Initialize List of Last Names
last_names = ["Castillo", "Hernandez", "Medina", "Salazar"]
first_names = ["James Iñaki", "Drixter", "Daryll John", "Angelica Mhay"]
prelim_grades = [1.75, 1.50, 1.25, 1.00]
midterm_grades = [1.00, 1.25, 1.50, 1.75]
finals_grades = [1.50, 1.75, 1.00, 1.25]

# %%
# Display Lists
print("Last Names:", last_names)
print("First Names:", first_names)
print("Prelim Grades:", prelim_grades)
print("Midterm Grades:", midterm_grades)
print("Finals Grades:", finals_grades)
# Out:
# Last Names: ['Castillo', 'Hernandez', 'Medina', 'Salazar']
# First Names: ['James Iñaki', 'Drixter', 'Daryll John', 'Angelica Mhay']
# Prelim Grades: [1.75, 1.5, 1.25, 1.0]
# Midterm Grades: [1.0, 1.25, 1.5, 1.75]
# Finals Grades: [1.5, 1.75, 1.0, 1.25]

# %%
to_df = [last_names, first_names, prelim_grades, midterm_grades, finals_grades] # Store the lists into a list
students_df = df(to_df).transpose() # Arrange the list Properly 
students_df.columns = ['Last Name', 'First Name', 'Prelim Grade', 'Midterm Grade', 'Finals Grade'] # Change the Column Names in the Dateframe
print(students_df)
# Out:
#    Last Name     First Name Prelim Grade Midterm Grade Finals Grade
# 0   Castillo    James Iñaki         1.75             1          1.5
# 1  Hernandez        Drixter          1.5          1.25         1.75
# 2     Medina    Daryll John         1.25           1.5            1
# 3    Salazar  Angelica Mhay            1          1.75         1.25

# %% [markdown]
# ### Task 2: Getting Class Statistics
# 1. Create a function named `get_grades()` for computing the semestral grade of each student:
#
#   `inputs`: `DataFrame` of a class grade sheet.
#
#   `outpus`: `DataFrame` showing:
#   * The prelim, midterms, and finals grades of each student
#   * The semestral grade of each student
#
# 2. Create a function named `get_class_stats()`.
#
#   `inputs`: `DataFrame` from `get_grades()`.
#
#   `outpus`: `DataFrame` showing:
#   * The lowest and highest prelim, midterm, finals, and semestral grades
#   * the mean, median, mode, and standard deviation of the grades

# %%
grades_df = pd.read_excel('/content/class_grades.xlsx')

# %%
grades_df.info() #Checking the information inside the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            27 non-null     object
#  1   id              27 non-null     int64
#  2   prelim_grades   26 non-null     float64
#  3   midterm_grades  27 non-null     float64
#  4   final_grades    27 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
# Data Preprocessing
## Replace NaN Values with 0

grades_df = grades_df.fillna(0)
grades_df
# Out:
#        name  id  prelim_grades  midterm_grades  final_grades
# 0     alpha   1      94.960000          95.260       92.2192
# 1     aleph   2      94.960000          95.260       92.7792
# 2      beta   3      78.173333          94.360       84.3200
# 3      beth   4      78.173333          81.372       84.6400
# 4    cuprum   5      94.960000          95.260       92.2192
# 5     delta   6      84.826667          92.485       83.5792
# 6       eta   7      93.980000          97.300       95.6528
# 7   epsilon   8      60.788200          68.000       83.8672
# 8   foxtrot   9      94.306667          82.000       84.1472
# 9     gamma  10      96.406667          82.000       84.1472
# 10     geld  11      86.926667          92.485       82.7792
# 11    horus  12      78.173333          94.360       84.3200
# 12     iota  13      94.306667          82.000       84.1472
# 13     ixus  14      78.173333          94.360       84.3200
# ...

# %%
# Gets the value of the dataframe
def get_grades(df): 
  df['semestral_grades'] = (df['prelim_grades']*.30) + (df['midterm_grades']*.30) + (df['final_grades']*.40) # Computes the semestral grades dataframe
  return df # Return to the get grades dataframe

get_grades(grades_df)
# Out:
#        name  id  prelim_grades  midterm_grades  final_grades  semestral_grades
# 0     alpha   1      94.960000          95.260       92.2192          93.95368
# 1     aleph   2      94.960000          95.260       92.7792          94.17768
# 2      beta   3      78.173333          94.360       84.3200          85.48800
# 3      beth   4      78.173333          81.372       84.6400          81.71960
# 4    cuprum   5      94.960000          95.260       92.2192          93.95368
# 5     delta   6      84.826667          92.485       83.5792          86.62518
# 6       eta   7      93.980000          97.300       95.6528          95.64512
# 7   epsilon   8      60.788200          68.000       83.8672          72.18334
# 8   foxtrot   9      94.306667          82.000       84.1472          86.55088
# 9     gamma  10      96.406667          82.000       84.1472          87.18088
# 10     geld  11      86.926667          92.485       82.7792          86.93518
# ...

# %%
def get_class_stats(df):
  # Get all the grades column from the dataframe
  grades = df[['prelim_grades', 'midterm_grades', 'final_grades', 'semestral_grades']]

  def max_min(grades):
    return grades.apply(lambda s: pd.Series([s.min(), s.max()],index=['Lowest', 'Highest'])) # Create a New Dataframe containing Highest and Lowest Grades

  def clt(grades):
    df['Mean'] = grades.mean(axis=1)
    df['Median'] = grades.median(axis=1)
    # A for loop is used to display the mode or its absence
    unique_grades = []
    for grade in grades:
      if grade not in unique_grades:
        unique_grades.append(grade)
    if len(set(unique_grades)) == 4:
      df['Mode'] = 'NaN'
    else: 
      df['Mode'] = grades.mode(axis=1)
    df['St dev'] = grades.std(axis=1)

  print("Lowest and Highest Grades Dataframe")
  print(max_min(grades))
  clt(grades)
 
get_class_stats(grades_df)
grades_df
# Out:
# Lowest and Highest Grades Dataframe
#          prelim_grades  midterm_grades  final_grades  semestral_grades
# Lowest        0.000000            68.0       50.3360          59.85238
# Highest      96.406667            97.3       95.6528          95.64512
#        name  id  prelim_grades  ...     Median  Mode     St dev
# 0     alpha   1      94.960000  ...  94.456840   NaN   1.371618
# 1     aleph   2      94.960000  ...  94.568840   NaN   1.108281
# 2      beta   3      78.173333  ...  84.904000   NaN   6.671908
# 3      beth   4      78.173333  ...  81.545800   NaN   2.645037
# 4    cuprum   5      94.960000  ...  94.456840   NaN   1.371618
# 5     delta   6      84.826667  ...  85.725923   NaN   3.940914
# 6       eta   7      93.980000  ...  95.648960   NaN   1.355398
# 7   epsilon   8      60.788200  ...  70.091670   NaN   9.662127
# 8   foxtrot   9      94.306667  ...  85.349040   NaN   5.369045
# 9     gamma  10      96.406667  ...  85.664040   NaN   6.348339
# ...

# %% [markdown]
# ### Task 3: Advanced Class Functions
# 1. Optimize `get_grades()` by eliminating for loops in your function.
# 2. Create a function named `get_similar_students()`
#
#   `inputs`: two (2) class `DataFrames`
#
#   `outputs`: list of common student numbers.
#
#   *Note*: The function should not contain iterative code blocks (i.e. `for` or `while` loops, or list comprehension)

# %% [markdown]
# ####Data Importation
# Importing the Excel file for comparison in a variable:
# class_grades.xlsx and comparison.xlsx

# %%
data1 = pd.read_excel('/content/class_listA.xlsx')
data2 = pd.read_excel('/content/class_listB.xlsx')

# %% [markdown]
# ####Data checking
# checking the each variable to know that the data is inside and correct.

# %%
data1
# Out:
#      201009754
# 0    201109795
# 1    201005713
# 2    201009855
# 3    201006171
# 4    201103568
# ..         ...
# 994  201108927
# 995  201005697
# 996  201005744
# 997  201109959
# 998  201109382
#
# [999 rows x 1 columns]

# %%
data2
# Out:
#      201103056
# 0    201105136
# 1    201002284
# 2    201104588
# 3    201004799
# 4    201005725
# ..         ...
# 994  201101346
# 995  201007625
# 996  201003815
# 997  201102428
# 998  201006876
#
# [999 rows x 1 columns]

# %% [markdown]
# ####Data Preprocess
# To help in comparing the two (2) dataframes we need to do a preprocessing method in filling out the NaN values in the data frame. Using a function we can create a preprocess method that uses dataframe as an input. Another function of the preprocessing method is to name the column that contains all the student numbers.

# %%
def preprocess(df):
  df.columns = ['Student_no.:']
  df = df.fillna(0)

preprocess(data1)
preprocess(data2)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_no.:  999 non-null    int64
# dtypes: int64(1)
# memory usage: 7.9 KB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_no.:  999 non-null    int64
# dtypes: int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# ####Data Comparison
# Using the function compare that is incorporated in Pandas package. We can check the similarties of each elements in both dataset.

# %%
data1.compare(data2, keep_equal=False)
# Out:
#     Student_no.:
#             self      other
# 0      201109795  201105136
# 1      201005713  201002284
# 2      201009855  201104588
# 3      201006171  201004799
# 4      201103568  201005725
# ..           ...        ...
# 994    201108927  201101346
# 995    201005697  201007625
# 996    201005744  201003815
# 997    201109959  201102428
# 998    201109382  201006876
#
# [999 rows x 2 columns]

# %% [markdown]
# ####Get similar students function
# Creating a function that takes an input of two (2) dataframes and then compare each other. The function will return a list of common students wrt ID number that is detected in both dataframe.

# %%
def get_similar(df_class1, df_class2):
  similar_df = pd.merge(left=df_class1, right=df_class2, left_on='Student_no.:', right_on='Student_no.:')
  stud_list = similar_df['Student_no.:'].tolist()
  return stud_list


similar_students = get_similar(data1,data2)
print(len(similar_students))
print(similar_students)
# Out:
# 64
# [201005821, 201008697, 201005415, 201009096, 201105430, 201109930, 201005367, 201007925, 201109299, 201002173, 201108238, 201006042, 201009820, 201009820, 201105857, 201009997, 201101893, 201101893, 201005822, 201102320, 201105259, 201106780, 201106199, 201102471, 201105592, 201102510, 201003675, 201102367, 201108241, 201108071, 201109056, 201002279, 201009157, 201003688, 201005275, 201102397, 201004454, 201105896, 201106739, 201005150, 201008775, 201009967, 201105318, 201109680, 201101996, 201103263, 201102318, 201109823, 201009671, 201103024, 201003730, 201104063, 201104594, 201108816, 201004865, 201007074, 201002245, 201005482, 201002849, 201007043, 201105295, 201009959, 201105014, 201008815]

# %% [markdown]
# ### Task 4: Class of Classes
# 1. Modify the `class` `Section` and integrate the functions from Tasks 1 to 3 as its methods. Make sure that the codes are optimized.
# 2. Create a `method` named `get_failed()` wherein it will create a list of all the failed students in the class.
# 3. Create a `method` named `fail_count()` wherein it will return the count of the failed students.
#
# ** **Note:** due to data privacy, the data privacy office has mandated your code to print the names of the failed students as well as to mask the names of the students if their grades are also displayed.

# %% [markdown]
# ####Creating class section
# Creating a class "section" will include functions from tasks 2 and 3 as its methods, such as function max_min and clt. Additionally, two methods are added, namely get_failed and fail_count, that will filter the student who got a semester grade lower than 70 and count their number. This method will return all necessary variables that are needed for each function.

# %%
class section:
  def __init__(self, df):
    self.df = df
    self.df['semestral_grades'] =  (self.df['prelim_grades']*.30) + (self.df['midterm_grades']*.30) + (self.df['final_grades']*.40)
    self.grades_col = df[['prelim_grades', 'midterm_grades', 'final_grades', 'semestral_grades']]

  def max_min(self):
    return self.grades_col.apply(lambda grade: pd.Series([grade.min(), grade.max()],index=['Lowest', 'Highest']))
  
  def clt(self):
    self.df['Mean'] = self.grades_col.mean(axis=1)
    self.df['Median'] = self.grades_col.median(axis=1)
    # A for loop is used to display the mode or its absence
    unique_grades = []
    for grade in self.grades_col:
      if grade not in unique_grades:
        unique_grades.append(grade)
    if len(set(unique_grades)) == 4:
      self.df['Mode'] = 'NaN'
    else: 
      self.df['Mode'] = self.grades_col.mode(axis=1)
    self.df['St dev'] = self.grades_col.std(axis=1)
    return self.df
    
  def get_failed(self):
    self.df['Remark'] = np.where(self.df['semestral_grades'] < 70, 'Failed', 'Passed')
    self.failed_df = self.df[(self.df['Remark']=='Failed')]
    return self.failed_df

  def fail_count(self):
    counter = len(self.failed_df)
    return "Total no. of Failed Students: " + str(counter)

# %%
class_data = section(grades_df)
print(class_data.max_min())
# Out:
#          prelim_grades  midterm_grades  final_grades  semestral_grades
# Lowest        0.000000            68.0       50.3360          59.85238
# Highest      96.406667            97.3       95.6528          95.64512

# %%
print(class_data.clt())
# Out:
#        name  id  prelim_grades  ...     Median  Mode     St dev
# 0     alpha   1      94.960000  ...  94.456840   NaN   1.371618
# 1     aleph   2      94.960000  ...  94.568840   NaN   1.108281
# 2      beta   3      78.173333  ...  84.904000   NaN   6.671908
# 3      beth   4      78.173333  ...  81.545800   NaN   2.645037
# 4    cuprum   5      94.960000  ...  94.456840   NaN   1.371618
# 5     delta   6      84.826667  ...  85.725923   NaN   3.940914
# 6       eta   7      93.980000  ...  95.648960   NaN   1.355398
# 7   epsilon   8      60.788200  ...  70.091670   NaN   9.662127
# 8   foxtrot   9      94.306667  ...  85.349040   NaN   5.369045
# 9     gamma  10      96.406667  ...  85.664040   NaN   6.348339
# 10     geld  11      86.926667  ...  86.930923   NaN   3.983004
# 11    horus  12      78.173333  ...  84.904000   NaN   6.671908
# 12     iota  13      94.306667  ...  85.349040   NaN   5.369045
# 13     ixus  14      78.173333  ...  84.904000   NaN   6.671908
# ...

# %% [markdown]
# ####Get the list of failed student function
# Creating a function that will filter the semestral grade from the data frame and get the list of students with less than 70 semestral grades. The function will return a list of all the failed students in the class.

# %%
print(class_data.get_failed())
# Out:
#      name  id  prelim_grades  midterm_grades  ...    Median  Mode     St dev  Remark
# 15  koppa  16          0.000          87.685  ...  71.85979   NaN  40.487257  Failed
# 19   neta  20         69.314          87.685  ...  68.27405   NaN  15.277208  Failed
#
# [2 rows x 11 columns]

# %% [markdown]
# ####Get the number of failed student function
# Creating a function that counts the number of failed students from the get_failed function above. The function returns the count of the failed students.

# %%
print(class_data.fail_count())
# Out:
# Total no. of Failed Students: 2
